# %% [markdown]
# # Overfitting and Regularization

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
from sklearn import set_config

# %%
set_config(display='diagram')

# %% [markdown]
# ## Settings

# %%
SEED = 42
RANGE = (-5, 5)
N_SAMPLES = 50
DEGREES = np.linspace(0, 15, 1 + 15, dtype=int)
ALPHAS = np.linspace(0, 0.5, 1 + 40)

# %% [markdown]
# ## Part 1: Underfitting vs. overfitting

# %% [markdown]
# ### Generate samples

# %% [markdown]
# Let's pick a target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ and generate some noisy samples to learn from.

# %%
def target_function(x):
    return 2 * x + 10 * np.sin(x)

def generate_samples():
    """Generate noisy samples."""
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    y = target_function(x) + np.random.normal(scale=4, size=N_SAMPLES)
    return x.reshape(-1, 1), y

X, y = generate_samples()

# %% [markdown]
# ### Plot samples

# %%
def plot_scatter(x, y, title=None, label='Noisy samples'):
    plt.scatter(x, y, label=label)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.title(title)
    plt.legend(loc='lower right')

plot_scatter(X, y)

# %% [markdown]
# ### Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=SEED)

plot_scatter(X_train, y_train, label='Training set')
plot_scatter(X_valid, y_valid, label='Validation set')

# %%
y_train
# Out:
# array([ -1.10771616,   0.84986647,  -9.62110024,   3.70972424,
#         -2.36319095,   5.83708039, -16.53330524,  -1.8815588 ,
#        -11.1506254 ,   1.0883081 ,  -9.05957818, -14.72254274,
#          5.71746212,   5.48508317,  -6.81897956,  -1.80751907,
#         -2.14124891, -12.83476672,  -0.09034969,  -3.48222266,
#         11.50001273,  -2.03019037,  10.03142993, -17.18409407,
#         -2.48182149,   1.67461593, -17.32081894,  -6.32825039,
#         -4.15121484,   9.31494651,   6.5817456 ,   6.58351686,
#         -1.83803375,  11.27589865,  13.68530977])

# %% [markdown]
# ### Model

# %% [markdown]
# Let's try to approximate our target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ with polynomials of different degree.
#
# A polynomial of degree $n$ has the form:
# $ h(x) = w_0 + w_1\cdot x + w_2\cdot x^2 +\ldots + w_n\cdot x^n $.
#
# $x^i$ values could easily be generated by `PolynomialFeatures`, while $w_i$ are the unknown paramaters to be estimated using `LinearRegression`.

# %%
PolynomialFeatures(degree=4, include_bias=False).fit_transform(X=[
    [1],
    [3],
    [4],
])
# Out:
# array([[  1.,   1.,   1.,   1.],
#        [  3.,   9.,  27.,  81.],
#        [  4.,  16.,  64., 256.]])

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    
    return Pipeline([
        ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
display(make_model(2, penalty='L1', alpha=0.1))
display(make_model(2, penalty='L2', alpha=0.1))
# Out:
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()), ('reg', LinearRegression())])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])

# %% [markdown]
# ### Fit

# %% [markdown]
# Let's fit a model and plot the hypothesis it learns:

# %%
def plot_fit(model):
    degree = model['pol'].degree
    X_range = np.linspace(*RANGE, 1000).reshape(-1, 1)
    y_pred = model.predict(X_range)
    plot_scatter(X_train, y_train, label='Training sample')
    plot_scatter(X_valid, y_valid, label='Validation sample')
    plt.plot(X_range, target_function(X_range), c='green', alpha=0.2, lw=5, label='Target function')
    plt.plot(X_range, y_pred, c='red', label='Hypothesis')
    plt.ylim((min(y) - 3, max(y) + 3))
    plt.legend(loc='best')    
    plt.title(f'Polynomial approximation: degree={degree}')
    plt.show()

plot_fit(make_model(degree=2).fit(X_train, y_train))

# %% [markdown]
# ### From underfitting to overfitting

# %% [markdown]
# We can investigate the shape of the fitted curve for different values of `degree`:

# %%
for degree in [0, 1, 2, 3, 4, 5, 10, 15, 20]:
    plot_fit(make_model(degree).fit(X_train, y_train))

# %% [markdown]
# ### Fitting graph

# %% [markdown]
# In the next step we calculate the training and the validation error for each `degree` and plot them in a single graph. The resulting graph is called the fitting graph.

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def plot_fitting_graph(x, metric_train, metric_valid, xlabel, ylabel, 
                       custom_metric=None, custom_label='', custom_scale='log', title='Fitting graph'):
    plt.figure(figsize=(9, 4.5))
    plt.plot(x, metric_train, label='Training')
    plt.plot(x, metric_valid, color='C1', label='Validation')
    plt.axvline(x[np.argmin(metric_valid)], color='C1', lw=10, alpha=0.2)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.xticks(x, rotation='vertical')
    plt.legend(loc='center left')        
    if custom_metric:
        plt.twinx()
        plt.yscale(custom_scale)
        plt.plot(x, custom_metric, alpha=0.2, lw=4, ls='dotted', color='black', label=custom_label) 
        plt.legend(loc='center right')         
    plt.show()
    
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Sweet spot

# %% [markdown]
# What is the optimal `degree` to go with?

# %%
DEGREES[np.argmin(rmse_valid)]
# Out:
# 5

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# Ideally, we would choose the the model parameters such that we have the best model performance. However, we want to make sure that we really have the best validation performance. When we do `train_test_split` we randomly split the data into two parts. What could happen is that we got lucky and split the data such that it favours the validation error. This is especially dangerous if we are dealing with small datasets. One way to check if that's the case is to run the experiment several times for different, random splits. However, there is an even more systematic way of doing this: [cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html).

# %% [markdown]
# <img src="https://scikit-learn.org/stable/_images/grid_search_cross_validation.png" width=50% />

# %%
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Model coefficients

# %% [markdown]
# Let's inspect our regression model coefficients:

# %%
(make_model(degree=1).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=2).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=5).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=10).fit(X_train, y_train)['reg'].coef_)
# Out:
# (array([2.81292778]),
#  array([2.80049884, 0.45166501]),
#  array([ 30.87315584,   1.48752361, -54.60227825,  -1.63699842,
#          26.62792933]),
#  array([  33.63850705,  -41.86346242,  -70.48743112,  278.98853452,
#           27.48125634, -656.36383501,   59.32988346,  651.64795186,
#          -47.55728814, -233.48455138]))

# %% [markdown]
# Hmm... it looks like high degree polynomials are coming with much bigger regression coefficients.
#
# We are going to plot the mean absolute value of $w_i$ as a function of degree to reveal the relationship:

# %%
rmse_train, rmse_valid, avg_coef = [], [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree),
                             X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))        
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Summary

# %% [markdown]
# We observe the following:
#
# 1. **Underfitting** (degree < 5): The model is not able to fit the data properly. The fit is bad for both the training and the validation set.
#
# 2. **Fit is just right** (degree = 5): The model is able to capture the underlying data distribution. The fit is good for both the training and the validation set.
#
# 3. **Overfitting** (degree > 5): The model starts fitting the noise in the dataset. While the fit for the training data gets even better, the fit for the validation set gets worse.
#
# 4. As the order of polynomial increases, the linear model coefficients become more likely to take on **large values**.

# %% [markdown]
# ## Part 2: Regularization

# %% [markdown]
# There are two major ways to build a machine learning model with the ability to generalize well on unseen data:
# 1. Train the simplest model possible for our purpose (according to Occam’s Razor).
# 2. Train a complex or more expressive model on the data and perform regularization.
#
# Regularization is a method used to reduce the variance of a machine learning model. In other words, it is used to reduce overfitting. Regularization penalizes a model for being complex. For linear models, it means regularization forces model coefficients to be smaller in magnitude.
#
# Let's pick a polynomial model of degree **15** (which tends to overfit strongly) and try to regularize it using **L1** and **L2** penalties.

# %% [markdown]
# ### L1 - Lasso regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L1', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %% [markdown]
# ### L2 - Ridge regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L2', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid, 
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)', 
                   title='Ridge polynomial regression (L2): degree=15')

# %% [markdown]
# ### Summary

# %% [markdown]
# 1. We can control the regularization strength by changing the hyperparameter `alpha`.
# 2. Regularized version of the model performs pretty well. Even in case the original original (unregularized) model is heavily overfitting due to excessive complexity.

# %% [markdown]
# ## Part 3: Homework assignment (10 points)

# %% [markdown]
# **WARNING!**
#
# Due to the limited power of your machine, you may face some difficulties in generating polynomial features of a high degree. It's ok to take only a subsample of features for that purpose (even one feature is enough). Afterwards, you **must collect all features together** (those which were used to generate polynomials and the rest).

# %% [markdown]
# ### Excercise 1 - Overfiting and Underfitting (2 points)

# %% [markdown]
# Let's work with the diabetes dataset

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
X_diabetes = pd.DataFrame(data['data'], columns=data['feature_names'])
y_diabetes = pd.DataFrame(data['target'], columns=['target'])
print(data['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# Apply model for diabetes dataset with polynomial feature engineering of different degrees. Plot the dependence of train and test error on polynomial degree. Highlight a degree with the best test error. Which degrees cause overfitting/underfitting? Why?

# %% [markdown]
# #### Let's apply model for diabets dataset with polynomial feature enginering of different degrees

# %% [markdown]
# Since my computer is NOT capable of raising all features to 15 degrees, I will use only 3 features.

# %% [markdown]
# Let's split the data first.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_diabetes, y_diabetes, test_size=0.3, random_state=SEED)

# %% [markdown]
# Let's import tqdm to see a progress bar for our loops.

# %%
import tqdm.notebook as tqdm

# %% [markdown]
# Let's rewrite make_model function so it has a ColumnTransformer which raises to degrees (uses PolynomialFeatures) only on certain features (in our case features age, sex, and bmi or with indexes 0, 1, 2).

# %%
from sklearn.compose import ColumnTransformer
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000)
    transformer = ColumnTransformer(transformers=[('poly', PolynomialFeatures(degree, include_bias=(degree == 0)), [0, 1, 2])])
    return Pipeline([
        ('pol', transformer),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
display(make_model(2, penalty='L1', alpha=0.1))
display(make_model(2, penalty='L2', alpha=0.1))
# Out:
# Pipeline(steps=[('pol',
#                  ColumnTransformer(transformers=[('poly',
#                                                   PolynomialFeatures(include_bias=False),
#                                                   [0, 1, 2])])),
#                 ('sca', StandardScaler()), ('reg', LinearRegression())])
# Pipeline(steps=[('pol',
#                  ColumnTransformer(transformers=[('poly',
#                                                   PolynomialFeatures(include_bias=False),
#                                                   [0, 1, 2])])),
#                 ('sca', StandardScaler()),
#                 ('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('pol',
#                  ColumnTransformer(transformers=[('poly',
#                                                   PolynomialFeatures(include_bias=False),
#                                                   [0, 1, 2])])),
#                 ('sca', StandardScaler()),
#                 ('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])

# %% [markdown]
# Now let's run the loop which will raise our features to different degrees (1-15), make a linear regression model and calculate RMSE for validation (test) data and train data.

# %%
DEGREES = np.linspace(0, 15, 1 + 15, dtype=int)
DEGREES = np.delete(DEGREES, 0)
rmse_train, rmse_valid = [], []
for degree in tqdm.tqdm(DEGREES):
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# #### Let's plot the dependence of train and test error on polynomial degree.

# %%
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression')

# %% [markdown]
# The graph above indicates with a vertical red line that a degree with which it is optimal to go is 2.

# %% [markdown]
# #### Let's highlight a degree with the best test error.

# %% [markdown]
# As I said the degree with the best error is 2. (To underline, if we raise into degrees all 15 features a degree with the best error would be 1).

# %% [markdown]
# Code below proves that a degree with the best error is 2.

# %%
DEGREES[np.argmin(rmse_valid)]
# Out:
# 2

# %% [markdown]
# #### Which degrees cause underfitting/overfitting? Why do I think so?

# %% [markdown]
# In order to better analyze which degrees cause underfitting/overfitting let's plot RMSE and use only degrees 1, 2, 3, 4, 5, so we can see better the beginning of the graph.

# %%
DEGREES = np.linspace(0, 5, 1 + 5, dtype=int)
DEGREES = np.delete(DEGREES, 0)
rmse_train, rmse_valid = [], []
for degree in tqdm.tqdm(DEGREES):
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression (degrees 1, 2, 3, 4, 5)')

# %% [markdown]
# Let's also provide a graph of RMSE with cross-validation and use only degrees 1, 2, 3, 4, 5 (What if we were lucky with the train/test split of the data).

# %%
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree), 
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression (degrees 1, 2, 3, 4, 5)')

# %% [markdown]
# As we can see from 2 graphs above, between 1 and 2 degrees the graphs for validation and train go down (RMSE decreases) indicating that model is still improving. Moreover, train and validation RMSE error are close. Consequently, I think that degree 1 causes underfitting.
#
# When degree is 2, it is optimal (it is neither underfitting or overfitting).
#
# When degrees are bigger than 2, the RMSE of validation becomes a lot bigger than RMSE of training and RMSE of validation in general goes up. Consequently, I think that degrees 3-15 cause overfitting.

# %% [markdown]
# #### Why certain degrees cause underfitting/overfitting?

# %% [markdown]
# The degree represents how much flexibility is in the model, a higher degree gives the model freedom to reach many data points.
#
# What happens in our case when degree is 1 is that the model is underfit - it is less flexible and cannot predict the data enough accurately. It has low variance and high bias. When degree is 1, the model depends little on the training data. It has a high bias - assumes that the data is linear, which is wrong in our case and leads to inaccurate estimates on test data. The model fails to learn the relationship between x and y because of this bias, causing underfitting.
#
# When degrees are 3 - 15, there is a high flexibility, the model does its best to reach every training point. We get a model with a high variance which will change significantly when the training data changes. The predictions on the test data are better than when degree is 1, but the 3-15 degrees models do not learn the relationship because they memorize the training data and test data is not a clone of a training data. We get an overfitted model, that makes mistakes on test data.
#
# Degree 2 found a balance between "memorizing" points in test data but not "memorizing" too much of them. That's why it gives great results on train data. If we had another dataset, the optimal degree could be different from degree 2.

# %% [markdown]
# ### Excercise 2 - Magnitude (3 points)

# %% [markdown]
# As discussed earlier, regularization methods are expected to constraint the weights (model coefficients).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### Implementation

# %% [markdown]
# Let's use L1 with cross-validation on our dataset and calculate 1) average (mean) coefficient for each model and 2) use what we calculated in 1) to calculate average (mean) coefficient for all models with one alpha (through cross-validation we get several models, because our data gets split into test and train several times.

# %% [markdown]
# #### L1

# %%
avg_coef = []
for alpha in tqdm.tqdm(ALPHAS):    
    results = cross_validate(make_model(degree=15, penalty='L1', alpha=alpha), 
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True,
                             return_estimator = True,
                             scoring='neg_root_mean_squared_error')
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.085e+04, tolerance: 2.153e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+04, tolerance: 2.044e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.112e+04, tolerance: 2.070e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e+04, tolerance: 2.156e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.698e+04, tolerance: 2.051e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.167e+03, tolerance: 2.153e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.651e+03, tolerance: 2.044e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.529e+03, tolerance: 2.070e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.559e+03, tolerance: 2.156e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.206e+03, tolerance: 2.051e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.569e+02, tolerance: 2.153e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.441e+03, tolerance: 2.044e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.688e+02, tolerance: 2.070e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.638e+02, tolerance: 2.051e+02
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Let's print our average coefficients.

# %%
avg_coef
# Out:
# [18597815.07297027,
#  6.294751752700977,
#  2.7920098627473657,
#  1.8551017492490647,
#  1.4369329984357573,
#  1.178966893165798,
#  1.0139012467297357,
#  0.888234893350831,
#  0.7826032880080914,
#  0.7027117302271135,
#  0.6304143986805866,
#  0.5746540940338919,
#  0.5276820961547378,
#  0.4869061955601842,
#  0.45168468978711607,
#  0.4238693127931691,
#  0.4004546492220425,
#  0.37919215163784875,
#  0.3614922820559898,
#  0.3453976319243376,
#  0.33137590095488606,
#  0.31865204785750467,
#  0.30634497995304766,
#  0.29479804991832864,
#  0.2838992417196732,
#  0.27334330183720573,
#  0.26505747315436523,
#  0.25748932555158077,
#  0.2510825030749538,
#  0.24499953429273771,
#  0.23858936391763255,
#  0.23296271231438254,
#  0.22749830798894224,
#  0.22227979467175718,
#  0.21755684768220213,
#  0.21332779668300134,
#  0.20945002714148891,
#  0.2058137905313171,
#  0.20224998179706383,
#  0.1986904028910054,
#  0.19536461950828213]

# %% [markdown]
# We can already see that average coefficient gets smaller with the increase of alpha. If average coefficient gets smaller and we have the same amount of coefficients, each coefficients also get smaller as well. In other words, coefficients are constraint by a regularization method called L1 (Lasso).

# %% [markdown]
# #### Graph of correlation between coefficients and alphas in L1 (with alpha 0/linear regression)

# %% [markdown]
# Let's plot the graph with X - average coefficient, Y - alphas for Lasso regression, to see clearly the relationship.

# %%
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS, avg_coef, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# The graph proves that average coefficient decreases (is constraint) with the increase of alpha when using regularization method called L1 (Lasso).

# %% [markdown]
# #### Graph of correlation between coefficients and alphas in L1 (without alpha 0/linear regression)

# %% [markdown]
# Because when alpha is 0, we get a linear regression without regularization, let's plot a graph without alpha equals 0.

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# Again, we see that average coefficient decreases as alpha increases.

# %% [markdown]
# Below you can see the same relationship but on a smaller case (we take first 6 alphas).

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
ALPHAS_without_0 = ALPHAS_without_0[0:6]
avg_coef_without_0 = avg_coef_without_0[0:6]
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# #### L2

# %% [markdown]
# Now let's explore the relationship between average coefficient and alphas in regularization method called L2 (Ridge). For that, Let's use L2 with cross-validation on our dataset and calculate 1) average (mean) coefficient for each model and 2) use what we calculated in 1) to calculate average (mean) coefficient for all models with one alpha (through cross-validation we get several models, because our data gets split into test and train several times.

# %%
avg_coef = []
for alpha in tqdm.tqdm(ALPHAS):    
    results = cross_validate(make_model(degree=15, penalty='L2', alpha=alpha), 
                             X_diabetes, y_diabetes, cv=5,
                             return_train_score=True,
                             return_estimator = True,
                             scoring='neg_root_mean_squared_error')
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %% [markdown]
# Let's print average coefficients that we got.

# %%
avg_coef
# Out:
# [18597815.07297027,
#  34.57554446281553,
#  25.06166452614833,
#  20.682945252802106,
#  17.987845599830287,
#  16.107781456669052,
#  14.705765786492814,
#  13.609842011302344,
#  12.722258785006963,
#  11.985998692013649,
#  11.363680216993325,
#  10.827928559820652,
#  10.360802863758439,
#  9.948740298935249,
#  9.580954434525456,
#  9.250009428949596,
#  8.95145042838619,
#  8.679494094557386,
#  8.431041443834987,
#  8.202268062487182,
#  7.990404452557144,
#  7.79423271464924,
#  7.6116155547824915,
#  7.440790997327686,
#  7.280843647056446,
#  7.130597334772725,
#  6.98889181073911,
#  6.85520154351755,
#  6.728698205866193,
#  6.6089192037468525,
#  6.495606689806683,
#  6.387934777856979,
#  6.285391632149738,
#  6.187628503340845,
#  6.094053963144756,
#  6.00437944573801,
#  5.918488288405685,
#  5.836130069364563,
#  5.756896113656044,
#  5.680680095287938,
#  5.607385936771214]

# %% [markdown]
# We can already say that when alpha increases, coefficients decrease (are constraint) by a regularization method called L2 (Ridge).

# %% [markdown]
# #### Graph of correlation between coefficients and alphas in L2 (with alpha 0/linear regression)¶

# %% [markdown]
# Let's plot the graph with X - average coefficient, Y - alphas for Ridge regression, to see clearly the relationship.

# %%
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS, avg_coef, label='Training')
plt.title('Correlation of average coefficients and alphas in L2 (Ridge regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# The graph proves that average coefficient decreases (is constraint) with the increase of alpha when using regularization method called L2 (Ridge).

# %% [markdown]
# #### Graph of correlation between coefficients and alphas in L2 (without alpha 0/linear regression)¶

# %% [markdown]
# Because when alpha is 0, we get a linear regression without regularization, let's plot a graph without alpha equals 0.

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L2 (Ridge regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# Again, we see that average coefficient decreases as alpha increases.

# %% [markdown]
# Below you can see the same relationship but on a smaller case (we take first 6 alphas).

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
ALPHAS_without_0 = ALPHAS_without_0[0:6]
avg_coef_without_0 = avg_coef_without_0[0:6]
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L2 (Ridge regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# #### Summary

# %% [markdown]
# As we can see from many graphs above with L1 (Lasso) and L2 (Ridge) the bigger the alphas, the small become coefficients (weights). Consequently, we can say that indeed it is happening - regularization methods constraint the weights (model coefficients). Weight get constraint because both L1 and L2 try to minimize the function and so with the increase of alphas they decrease weights. It happens becayse L1 adds a penalty - multiplies alpha by the sum of absolute values of the weights and L2 adds a penalty - multiplies alpha by the sum of squares of the weights.

# %% [markdown]
# ### Excercise 3 - Sparsity (3 points)

# %% [markdown]
# Lasso can also be used for **feature selection** since L1 is [more likely to produce zero coefficients](https://explained.ai/regularization/).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %% [markdown]
# To find how many zero coefficients L1 produces, let's store all coefficients after using a loop for alpha in Alphas in an all_coefficients array. Moreover, we will calculate the percent of zero weights for each alpha.

# %%
all_coefficients = []
percent_of_coefficients_for_alpha = []
for the_alpha in tqdm.tqdm(ALPHAS):    
    reg = make_model(15, penalty='L1', alpha=the_alpha).fit(X_train, y_train)
    coefficients = reg.named_steps['reg'].coef_.reshape(-1)
    all_coefficients.extend(coefficients)
    #get amount of coefficients
    amount_of_coefficients = len(coefficients)
    #get amount of zero coefficients
    zero_coefficients = coefficients.tolist().count(0)
    percent_of_coefficients_for_alpha.append(zero_coefficients/amount_of_coefficients)
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.241e+04, tolerance: 1.900e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+04, tolerance: 1.900e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.475e+02, tolerance: 1.900e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.356e+02, tolerance: 1.900e+02
#   model = cd_fast.enet_coordinate_descent(
# D:\MiniConda\envs\rsschool-machine-learning-course\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.395e+02, tolerance: 1.900e+02
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Let's count how many zero weights the array has.

# %%
zero_weights_amount = all_coefficients.count(0)
zero_weights_amount
# Out:
# 30720

# %% [markdown]
# As we can see that L1 produced 30720 zero weights.

# %% [markdown]
# Let's calculate the percent of zero weight from all weights that we have.

# %%
zero_weights_amount/len(all_coefficients)
# Out:
# 0.9193475983839593

# %% [markdown]
# Let's draw a graph of correlation between percent of zero weights and alphas.

# %%
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS, percent_of_coefficients_for_alpha, label='Training')
plt.title('Correlation of percent of zero weights produced by a L1 and alphas')
plt.xlabel('alphas')
plt.ylabel('Percent of zero weights')
plt.xticks(ALPHAS, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# As we can see the percent of zero weights increased significantly from 0 alpha to next alpha. After that the percent of zero weight slowly increases as alpha increases.

# %% [markdown]
# Slow increase of the percent of zero weights as alpha increases is seen better if we delete alpha = 0 from our graph (I did it below).

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
percent_of_coefficients_for_alpha_without_0 = np.delete(percent_of_coefficients_for_alpha, 0)
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, percent_of_coefficients_for_alpha_without_0, label='Training')
plt.title('Correlation of percent of zero weights produced by a L1 and alphas')
plt.xlabel('alphas')
plt.ylabel('Percent of zero weights')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# To conclude, L1 produces lots of zero weights. To underline, the exact amount of zero weight produced may differ between datasets.

# %% [markdown]
# #### L2

# %% [markdown]
# To find how many zero coefficients L2 produces, let's store all coefficients after using a loop for alpha in Alphas in an all_coefficients array. Moreover, we will calculate the percent of zero weights for each alpha.

# %%
all_coefficients = []
percent_of_coefficients_for_alpha = []
for the_alpha in tqdm.tqdm(ALPHAS):    
    reg = make_model(15, penalty='L2', alpha=the_alpha).fit(X_train, y_train)
    coefficients = reg.named_steps['reg'].coef_.reshape(-1)
    all_coefficients.extend(coefficients)
    #get amount of coefficients
    amount_of_coefficients = len(coefficients)
    #get amount of zero coefficients
    zero_coefficients = coefficients.tolist().count(0)
    percent_of_coefficients_for_alpha.append(zero_coefficients/amount_of_coefficients)
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %% [markdown]
# Let's count how many zero weights the array has.

# %%
zero_weights_amount = all_coefficients.count(0)
zero_weights_amount
# Out:
# 0

# %% [markdown]
# We have got 0 zero weights for L2. Consequently, there is no use in presenting the percent or drawing any graphs here.

# %% [markdown]
# #### Summary

# %% [markdown]
# As we can see from findings above, L1 (Lasso) produced 30720 zero weights which is 91% of all features. Moreover, from the graph we saw that - when alpha increases, the percent of zero weights produced increases. However, L2 (Ridge) produced no zero weights.
#
# Consequently, it is indeed happening that L1 is more likely to produce zero coefficients (weights). Moreover, L2 is trying to minimize weights, make them as much close to 0 as possible. Also, yes, Lasso can also be used for feature selection because if L1 produces zero weight, than a feature associated with weight is useless because 0 * feature = 0, so we can ommit it. Similar situation is with L2, if weight becomes close to zero, than it hardly (almost doesn't) influences the model.

# %% [markdown]
# ### Excercise 4 - Scaling (2 points)

# %% [markdown]
# As a general rule, it is recommended to scale input features before fitting a regularized model so that the features/inputs take values in similar ranges. One common way of doing so is to standardize the inputs and that is exactly what our pipeline  second step (`StandardScaler`) is responsible for.
#
# Is scaling important? What are the underlying reasons?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**) on the dataset below. Check coefficients.

# %%
def target_function_hw(x):
    return 2 * x

def generate_samples_hw():
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    
    np.random.seed(SEED+1)
    x_noise = np.random.uniform(*[x * 100 for x in RANGE], size=N_SAMPLES)
    x_noise2 = np.random.normal(100, 50, size=N_SAMPLES)
    
    y = target_function_hw(x) + np.random.normal(scale=4, size=N_SAMPLES)
    
    return np.concatenate([x.reshape(-1, 1) / 100, 
                           x_noise.reshape(-1, 1),
                           x_noise2.reshape(-1, 1)], axis=1), y

X_hw, y_hw = generate_samples_hw()

for i in range(X_hw.shape[1]):
    print(f'Min of feature {i}: {min(X_hw[:, i]):.2f}, max: {max(X_hw[:, i]):.2f}')
# Out:
# Min of feature 0: -0.05, max: 0.05
# Min of feature 1: -494.87, max: 493.57
# Min of feature 2: -2.35, max: 213.31

# %% [markdown]
# #### L1

# %% [markdown]
# #### With Scaling

# %% [markdown]
# #### RMSE

# %% [markdown]
# Let's see what RMSE our model has when features ARE SCALED. For that we will use a make_model function which contains scalling.

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
rmse_train, rmse_valid = [], []
for alpha in ALPHAS_without_0:    
    results = cross_validate(make_model(degree=1, penalty='L1', alpha=alpha), 
                             X_hw, y_hw, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS_without_0, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %% [markdown]
# #### Average coefficient

# %% [markdown]
# Let's see what average coefficients our mode has when features ARE SCALLED.

# %%
avg_coef = []
for alpha in tqdm.tqdm(ALPHAS):    
    results = cross_validate(make_model(degree=1, penalty='L1', alpha=alpha), 
                             X_hw, y_hw, cv=5,
                             return_train_score=True,
                             return_estimator = True,
                             scoring='neg_root_mean_squared_error')
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# #### Average coefficient for each feature

# %%
avg_coef_1 = []
avg_coef_2 = []
avg_coef_3 = []
for alpha in tqdm.tqdm(ALPHAS):    
    results = cross_validate(make_model(degree=1, penalty='L1', alpha=alpha), 
                             X_hw, y_hw, cv=5,
                             return_train_score=True,
                             return_estimator = True,
                             scoring='neg_root_mean_squared_error')
    for model in results['estimator']:
        avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            
        ]))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# [ 1.64068055e+02  1.58551758e-03 -4.69773979e-03]
# [ 1.81559627e+02 -4.35773681e-04 -1.10791761e-02]
# [ 1.76320180e+02  8.05682355e-04 -1.11796224e-02]
# [ 1.91982324e+02 -4.24617412e-04 -1.47089847e-02]
# [ 1.80830862e+02  7.82970136e-04 -1.80964267e-02]
# [ 1.47483176e+02  1.57943322e-03 -6.74462598e-03]
# [ 1.65941355e+02 -5.66923867e-04 -1.13873534e-02]
# [ 1.62203727e+02  6.86812736e-04 -1.13619458e-02]
# [ 1.74950951e+02 -6.08196978e-04 -1.43695021e-02]
# [ 1.65967435e+02  9.20737687e-04 -1.86548630e-02]
# [ 1.30898228e+02  1.57334622e-03 -8.79152224e-03]
# [ 1.50323080e+02 -6.98074087e-04 -1.16955308e-02]
# [ 1.48087274e+02  5.67943034e-04 -1.15442691e-02]
# [ 1.57919877e+02 -7.91769169e-04 -1.40300282e-02]
# [ 1.51104002e+02  1.05850540e-03 -1.92132996e-02]
# [ 1.14313279e+02  1.56725922e-03 -1.08384185e-02]
# [ 1.34704806e+02 -8.29224307e-04 -1.20037081e-02]
# [ 1.33970821e+02  4.49073332e-04 -1.17265925e-02]
# [ 1.40888803e+02 -9.75341361e-04 -1.36905544e-02]
# [ 1.36240570e+02  1.19627311e-03 -1.97717362e-02]
# [ 9.77283308e+01  1.56117222e-03 -1.28853148e-02]
# [ 1.19086532e+02 -9.60374527e-04 -1.23118855e-02]
# [ 1.19854368e+02  3.30203630e-04 -1.19089158e-02]
# [ 1.23857729e+02 -1.15891355e-03 -1.33510805e-02]
# [ 1.21377137e+02  1.33404082e-03 -2.03301728e-02]
# [ 8.11433823e+01  1.55508522e-03 -1.49322110e-02]
# [ 1.03468258e+02 -1.09152475e-03 -1.26200629e-02]
# [ 1.05737915e+02  2.11333929e-04 -1.20912392e-02]
# [ 1.06826656e+02 -1.34248574e-03 -1.30116066e-02]
# [ 1.06513704e+02  1.47180853e-03 -2.08886093e-02]
# [ 6.45584339e+01  1.54899822e-03 -1.69791073e-02]
# [ 8.78499833e+01 -1.22267497e-03 -1.29282403e-02]
# [ 9.16214615e+01  9.24642269e-05 -1.22735625e-02]
# [ 8.97955819e+01 -1.52605794e-03 -1.26721327e-02]
# [ 9.16502711e+01  1.60957624e-03 -2.14470459e-02]
# [ 4.79732346e+01  1.54290174e-03 -1.90260397e-02]
# [ 7.22317090e+01 -1.35382519e-03 -1.32364176e-02]
# [ 7.75066704e+01 -2.45290287e-05 -1.24563335e-02]
# [ 7.27645082e+01 -1.70963013e-03 -1.23326589e-02]
# [ 7.67868383e+01  1.74734395e-03 -2.20054825e-02]
# [ 3.13882599e+01  1.53681375e-03 -2.10729397e-02]
# [ 5.66134348e+01 -1.48497541e-03 -1.35445950e-02]
# [ 6.33904547e+01 -1.43130667e-04 -1.26387208e-02]
# [ 5.57334344e+01 -1.89320232e-03 -1.19931850e-02]
# [ 6.19234055e+01  1.88511166e-03 -2.25639191e-02]
# [ 1.48032853e+01  1.53072576e-03 -2.31198397e-02]
# [ 4.09951605e+01 -1.61612563e-03 -1.38527724e-02]
# [ 4.92742391e+01 -2.61732305e-04 -1.28211081e-02]
# [ 3.87025465e+01 -2.07676997e-03 -1.16537165e-02]
# [ 4.70599726e+01  2.02287938e-03 -2.31223556e-02]
# [ 0.          0.00152529 -0.02494609]
# [ 2.53768862e+01 -1.74727585e-03 -1.41609497e-02]
# [ 3.51580235e+01 -3.80333943e-04 -1.30034954e-02]
# [ 2.16714612e+01 -2.26034245e-03 -1.13142423e-02]
# [ 3.21965398e+01  2.16064709e-03 -2.36807922e-02]
# [ 0.          0.00152523 -0.02493904]
# [ 9.75861194e+00 -1.87842607e-03 -1.44691271e-02]
# [ 2.10418079e+01 -4.98935581e-04 -1.31858827e-02]
# [ 4.64037592e+00 -2.44391493e-03 -1.09747680e-02]
# [ 1.73331070e+01  2.29841480e-03 -2.42392288e-02]
# [ 0.          0.00152517 -0.02493199]
# [ 0.         -0.00196035 -0.0146598 ]
# [ 6.92559359e+00 -6.17537305e-04 -1.33682699e-02]
# [ 0.        -0.0024939 -0.0108783]
# [ 2.46966550e+00  2.43618274e-03 -2.47976658e-02]
# [ 0.          0.00152511 -0.02492494]
# [ 0.         -0.00196031 -0.01465479]
# [ 0.         -0.00067567 -0.01345542]
# [ 0.         -0.00249386 -0.01087283]
# [ 0.          0.00245891 -0.02488665]
# [ 0.          0.00152505 -0.0249179 ]
# [ 0.         -0.00196026 -0.01464977]
# [ 0.         -0.00067557 -0.01345084]
# [ 0.         -0.00249381 -0.01086736]
# [ 0.          0.00245873 -0.0248821 ]
# [ 0.          0.00152499 -0.02491085]
# [ 0.         -0.00196021 -0.01464476]
# [ 0.         -0.00067548 -0.01344626]
# [ 0.         -0.00249377 -0.01086189]
# [ 0.          0.00245855 -0.02487754]
# [ 0.          0.00152493 -0.0249038 ]
# [ 0.         -0.00196016 -0.01463974]
# [ 0.         -0.00067538 -0.01344168]
# [ 0.         -0.00249372 -0.01085642]
# [ 0.          0.00245836 -0.02487299]
# [ 0.          0.00152487 -0.02489675]
# [ 0.         -0.00196011 -0.01463473]
# [ 0.         -0.00067528 -0.0134371 ]
# [ 0.         -0.00249368 -0.01085096]
# [ 0.          0.00245818 -0.02486843]
# [ 0.          0.00152481 -0.02488971]
# [ 0.         -0.00196006 -0.01462972]
# [ 0.         -0.00067518 -0.01343253]
# [ 0.         -0.00249364 -0.01084549]
# [ 0.          0.00245799 -0.02486388]
# [ 0.          0.00152475 -0.02488266]
# [ 0.         -0.00196002 -0.0146247 ]
# [ 0.         -0.00067508 -0.01342795]
# [ 0.         -0.00249359 -0.01084002]
# [ 0.          0.00245781 -0.02485932]
# [ 0.          0.0015247  -0.02487561]
# [ 0.         -0.00195997 -0.01461969]
# [ 0.         -0.00067498 -0.01342337]
# [ 0.         -0.00249355 -0.01083455]
# [ 0.          0.00245763 -0.02485477]
# [ 0.          0.00152464 -0.02486856]
# [ 0.         -0.00195992 -0.01461467]
# [ 0.         -0.00067488 -0.01341879]
# [ 0.         -0.0024935  -0.01082909]
# [ 0.          0.00245744 -0.02485021]
# [ 0.          0.00152458 -0.02486152]
# [ 0.         -0.00195987 -0.01460966]
# [ 0.         -0.00067478 -0.01341421]
# [ 0.         -0.00249346 -0.01082362]
# [ 0.          0.00245726 -0.02484565]
# [ 0.          0.00152452 -0.02485447]
# [ 0.         -0.00195982 -0.01460464]
# [ 0.         -0.00067468 -0.01340963]
# [ 0.         -0.00249342 -0.01081815]
# [ 0.          0.00245708 -0.0248411 ]
# [ 0.          0.00152446 -0.02484742]
# [ 0.         -0.00195978 -0.01459963]
# [ 0.         -0.00067458 -0.01340505]
# [ 0.         -0.00249337 -0.01081268]
# [ 0.          0.00245689 -0.02483654]
# [ 0.          0.0015244  -0.02484037]
# [ 0.         -0.00195973 -0.01459462]
# [ 0.         -0.00067448 -0.01340048]
# [ 0.         -0.00249333 -0.01080721]
# [ 0.          0.00245671 -0.02483199]
# [ 0.          0.00152434 -0.02483333]
# [ 0.         -0.00195968 -0.0145896 ]
# [ 0.         -0.00067438 -0.0133959 ]
# [ 0.         -0.00249328 -0.01080175]
# [ 0.          0.00245652 -0.02482743]
# [ 0.          0.00152428 -0.02482628]
# [ 0.         -0.00195963 -0.01458459]
# [ 0.         -0.00067428 -0.01339132]
# [ 0.         -0.00249324 -0.01079628]
# [ 0.          0.00245634 -0.02482288]
# [ 0.          0.00152422 -0.02481923]
# [ 0.         -0.00195958 -0.01457957]
# [ 0.         -0.00067418 -0.01338674]
# [ 0.         -0.0024932  -0.01079081]
# [ 0.          0.00245616 -0.02481832]
# [ 0.          0.00152416 -0.02481219]
# [ 0.         -0.00195953 -0.01457456]
# [ 0.         -0.00067408 -0.01338216]
# [ 0.         -0.00249315 -0.01078534]
# [ 0.          0.00245597 -0.02481377]
# [ 0.          0.0015241  -0.02480514]
# [ 0.         -0.00195949 -0.01456954]
# [ 0.         -0.00067398 -0.01337758]
# [ 0.         -0.00249311 -0.01077988]
# [ 0.          0.00245579 -0.02480921]
# [ 0.          0.00152404 -0.02479809]
# [ 0.         -0.00195944 -0.01456453]
# [ 0.         -0.00067388 -0.013373  ]
# [ 0.         -0.00249306 -0.01077441]
# [ 0.          0.00245561 -0.02480466]
# [ 0.          0.00152398 -0.02479104]
# [ 0.         -0.00195939 -0.01455952]
# [ 0.         -0.00067378 -0.01336843]
# [ 0.         -0.00249302 -0.01076894]
# [ 0.          0.00245542 -0.0248001 ]
# [ 0.          0.00152392 -0.024784  ]
# [ 0.         -0.00195934 -0.0145545 ]
# [ 0.         -0.00067368 -0.01336385]
# [ 0.         -0.00249297 -0.01076347]
# [ 0.          0.00245524 -0.02479555]
# [ 0.          0.00152386 -0.02477695]
# [ 0.         -0.00195929 -0.01454949]
# [ 0.         -0.00067359 -0.01335927]
# [ 0.         -0.00249293 -0.01075801]
# [ 0.          0.00245505 -0.02479099]
# [ 0.         0.0015238 -0.0247699]
# [ 0.         -0.00195925 -0.01454447]
# [ 0.         -0.00067349 -0.01335469]
# [ 0.         -0.00249289 -0.01075254]
# [ 0.          0.00245487 -0.02478644]
# [ 0.          0.00152374 -0.02476285]
# [ 0.         -0.0019592  -0.01453946]
# [ 0.         -0.00067339 -0.01335011]
# [ 0.         -0.00249284 -0.01074707]
# [ 0.          0.00245469 -0.02478188]
# [ 0.          0.00152368 -0.02475581]
# [ 0.         -0.00195915 -0.01453444]
# [ 0.         -0.00067329 -0.01334553]
# [ 0.        -0.0024928 -0.0107416]
# [ 0.          0.0024545  -0.02477732]
# [ 0.          0.00152362 -0.02474876]
# [ 0.         -0.0019591  -0.01452943]
# [ 0.         -0.00067319 -0.01334095]
# [ 0.         -0.00249275 -0.01073613]
# [ 0.          0.00245432 -0.02477277]
# [ 0.          0.00152356 -0.02474171]
# [ 0.         -0.00195905 -0.01452442]
# [ 0.         -0.00067309 -0.01333638]
# [ 0.         -0.00249271 -0.01073067]
# [ 0.          0.00245414 -0.02476821]
# [ 0.          0.0015235  -0.02473466]
# [ 0.         -0.00195901 -0.0145194 ]
# [ 0.         -0.00067299 -0.0133318 ]
# [ 0.         -0.00249267 -0.0107252 ]
# [ 0.          0.00245395 -0.02476366]

# %% [markdown]
# #### Zero weights

# %% [markdown]
# #### Without Scaling

# %% [markdown]
# Now let's declare make_model function again but drop the part about scaling.

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    
    return Pipeline([
        ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
        ('reg', regressor)
    ])

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
rmse_train, rmse_valid = [], []
for alpha in ALPHAS_without_0:    
    results = cross_validate(make_model(degree=1, penalty='L1', alpha=alpha), 
                             X_hw, y_hw, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS_without_0, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %%
avg_coef = []
for alpha in tqdm.tqdm(ALPHAS):    
    results = cross_validate(make_model(degree=1, penalty='L1', alpha=alpha), 
                             X_hw, y_hw, cv=5,
                             return_train_score=True,
                             return_estimator = True,
                             scoring='neg_root_mean_squared_error')
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS, avg_coef, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %%
ALPHAS_without_0 = np.delete(ALPHAS, 0)
avg_coef_without_0 = np.delete(avg_coef, 0)
plt.figure(figsize=(9, 4.5))
plt.plot(ALPHAS_without_0, avg_coef_without_0, label='Training')
plt.title('Correlation of average coefficients and alphas in L1 (Lasso regression)')
plt.xlabel('alphas')
plt.ylabel('Average coefficient')
plt.xticks(ALPHAS_without_0, rotation='vertical')
plt.grid(True)
plt.legend(loc='center left')        
plt.show()

# %% [markdown]
# #### L2

# %%
## your code

# %% [markdown]
# #### Summary

# %% [markdown]
# Similarly, in many machine learning algorithms, to bring all features in the same standing, we need to do scaling so that one significant number doesn’t impact the model just because of their large magnitude.
#
# Machine learning algorithm just sees number — if there is a vast difference in the range say few ranging in thousands and few ranging in the tens, and it makes the underlying assumption that higher ranging numbers have superiority of some sort. So these more significant number starts playing a more decisive role while training the model.
# The machine learning algorithm works on numbers and does not know what that number represents. A weight of 10 grams and a price of 10 dollars represents completely two different things — which is a no brainer for humans, but for a model as a feature, it treats both as same.
#
# So these more significant number starts playing a more decisive role while training the model. Thus feature scaling is needed to bring every feature in the same footing without any upfront importance.

# %% [markdown]
# 1. Плохо, потому что ошибка растёт?
# 2. Плохо, потому что средний коэффициент меньше уменьшается?
# 3. Плохо, потому что нулей меньше?

# %% [markdown]
# The machine learning models provide weights to the input variables according to their data points and inferences for output. In that case, if the difference between the data points is so high, the model will need to provide the larger weight to the points and in final results, the model with a large weight value is often unstable. This means the model can produce poor results or can perform poorly during learning.

# %% [markdown]
# Machine learning algorithms like linear regression, logistic regression using this algorithm as their basic function. Gradient descent is a first-order iterative optimization algorithm for finding a local minimum of a different function. Basically in any algorithm, the gradient descent function slides through the data set while applied to the data set, step by step. So if the distance between the data points increases the size of the step will change and the movement of the function will not be smooth. Take a look at the formula.
#
# Here x represents the feature value and theta represents the movement of the function or optimization function. So if the distance range between feature values increases the movement will increase and function will not work properly. In that situation, we will be required to have a data set well rescaled so that the function can better help in the development of the machine learning model.

# %% [markdown]
# When your model includes these types of terms, you are at risk of producing misleading results and missing statistically significant terms.
